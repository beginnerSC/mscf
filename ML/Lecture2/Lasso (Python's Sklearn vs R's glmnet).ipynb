# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn import linear_model
from sklearn.linear_model import lasso_path, enet_path
from itertools import cycle

import matplotlib.pyplot as plt

# %% [markdown]
# # Lasso in Sklearn
#
# ## data loading

# %%
retmat = pd.read_csv(
    "HedgeFundReplication/replicatingHDG.dat", 
    sep = " ")

X = retmat.copy()
X = X.drop(labels = "HDG", axis=1)

y = retmat["HDG"]

# %%
X.shape
# Out:
# (183, 1961)

# %% [markdown]
# ## Lasso in Sklearn with LassoCV

# %%
from sklearn.linear_model import LassoCV

n_folds = 10
clf3 = LassoCV(n_alphas = 100, cv = n_folds, normalize = True)
clf3.fit(X, y);

# %% [markdown]
# ## Graphic visualization of CV MSE vs $\alpha$ level

# %%
alpha_range = clf3.alphas_
mse_values = clf3.mse_path_.mean(axis = 1)
sd_values = clf3.mse_path_.std(axis = 1)

plt.plot(np.log(alpha_range), mse_values ,"k-o")
plt.plot(np.log(alpha_range), mse_values + sd_values,"r--")
plt.plot(np.log(alpha_range), mse_values - sd_values,"r--")
plt.fill_between(np.log(alpha_range),
                mse_values + sd_values,
                mse_values - sd_values, alpha = .2)

plt.plot([np.log(clf3.alpha_)]*2, [0,.000045])
plt.xlabel(r"$log(\alpha)$")
plt.ylabel("10-Fold CV MSE");

# %%
plt.show()

# %% [markdown]
# ## Sparse $\beta$ statistics from Optimal Model
# Note: Sklearn takes the model with $\alpha_\text{min}$

# %%
# beta values
clf3.coef_

summary_table = pd.DataFrame({
    "names": np.array(retmat.columns)[:-1][clf3.coef_!=0],
    "beta values": clf3.coef_[clf3.coef_!=0]
}, columns = ["names","beta values"])


summary_table
# Out:
#    names  beta values
# 0    GCH     0.019153
# 1    JEQ     0.001663
# 2    AFL     0.008402
# 3      B     0.000247
# 4    BDC     0.012896
# 5    BIO     0.001029
# 6    CII     0.006733
# 7    BGY     0.008492
# 8    CBG     0.012403
# 9    CEB     0.002052
# 10   KOF     0.001893
# 11   CNS     0.004239
# 12   CVG     0.001214
# 13   EVC     0.002335
# 14   FMX     0.001040
# 15   GAM     0.012176
# 16   GPN     0.000287
# 17   HSC     0.002431
# 18   HLS     0.013112
# 19   HII     0.005029
# 20     H     0.003876
# 21   JAH     0.001857
# 22    KR     0.001765
# 23   LGI     0.012324
# 24    MD     0.013374
# 25   MSF     0.047328
# 26   IIF     0.002552
# 27   DCM     0.003825
# 28    OC     0.002330
# 29    OI     0.001450
# 30   SSD     0.001636
# 31   SNN     0.003295
# 32   SYK     0.001148
# 33   TTM     0.001656
# 34   EMF     0.004526
# 35   TMK     0.010569
# 36    TM     0.002681
# 37    TY     0.037822
# 38    UN     0.002997
# 39   URI     0.002262

# %% [markdown]
# # R
#
# The version that is better.
#
# ### Data

# %%
import rpy2
# %load_ext rpy2.ipython

# %%
# %%R -i retmat
# retmat = as.matrix(retmat)

# %% [markdown]
# ### glmnet code

# %%
# %%R
# library(glmnet)
#
# # Get the data for the stock under consideration
# # Note that the final column holds the response
#
# glmnetout = glmnet(retmat[,-1962], retmat[,1962])

# %%
# %%R
# # Use cross-validation to choose optimal lambda. Note that this procedure is random.
# set.seed(0)
#
# cvglmout = cv.glmnet(retmat[,-1962], retmat[,1962])

# %% [markdown]
# ### Plots

# %%
# %%R
# plot(cvglmout,lwd=2)
# abline(v=log(cvglmout$lambda.min),lty=3,lwd=2)
# abline(v=log(cvglmout$lambda.1se),lty=3,lwd=2)

# %%
# %%R
# beta_lasso = coef(glmnetout, s=cvglmout$lambda.1se)
#
#
# print(beta_lasso)
# Out:
# 1962 x 1 sparse Matrix of class "dgCMatrix"
#                         1
# (Intercept) -0.0001066996
# DDD          .
# MMM          .
# AHC          .
# AIR          .
# AAN          .
# ABB          .
# ABT          .
# ANF          .
# GCH          .
# JEQ          .
# SGF          .
# ABM          .
# AKR          .
# ACN          .
# ACCO         .
# ACW          .
# ACE          .
# ATV          .
# ATU          .
# AYI          .
# ADX          .
# PEO          .
# AGRO         .
# AAP          .
# ASX          .
# AAV          .
# ATE          .
# AVK          .
# AGC          .
# LCM          .
# ACM          .
# ANW          .
# AEB          .
# AED          .
# AEG          .
# AEH          .
# AER          .
# AJRD         .
# ARO          .
# AET          .
# AMG          0.0011158914
# AFL          0.0028075581
# MITT         .
# AGCO         .
# A            .
# GAS          .
# AEM          .
# ADC          .
# GRO          .
# AGU          .
# AL           .
# APD          .
# AYR          .
# ARG          .
# AKS          .
# ALG          .
# AGI          .
# ALK          .
# AIN          .
# ALB          .
# ALU          .
# AA           .
# ALR          .
# ALX          .
# ARE          .
# Y            .
# ATI          .
# AGN          .
# ALE          .
# AKP          .
# ADS          .
# AFB          .
# AOI          .
# AWF          .
# AB           .
# ACG          .
# LNT          .
# NCV          .
# NCZ          .
# NIE          .
# NFJ          .
# AWH          .
# ALL          .
# BSI          .
# ALJ          .
# AGD          .
# AWP          .
# AOD          .
# MO           .
# ACH          .
# ABEV         .
# AEE          .
# AMRC         .
# AMX          .
# AAT          .
# AXL          .
# ACC          .
# AEO          .
# AEP          .
# AEL          .
# AXP          .
# AFG          .
# AIG          .
# AMID         .
# ARL          .
# AWR          .
# AMT          .
# AVD          .
# AWK          .
# APU          .
# AMP          .
# ABC          .
# AHS          .
# AP           .
# APH          .
# AXR          .
# AME          .
# APC          .
# AU           .
# BUD          .
# AXE          .
# NLY          .
# ANTM         .
# ANH          .
# AON          .
# APA          .
# AIV          .
# ARI          .
# APO          .
# AMTG         .
# AFT          .
# AIT          .
# ATR          .
# WTR          .
# ABR          .
# ARC          .
# MT           .
# ACI          .
# ADM          .
# AROC         .
# ARCO         .
# AFC          .
# AGX          .
# AI           .
# ARR          .
# AWI          .
# ARW          .
# AJG          .
# ASA          .
# ABG          .
# AHT          .
# ASH          .
# APB          .
# GRR          .
# AHL          .
# ASB          .
# AIZ          .
# AGO          .
# AF           .
# AZN          .
# T            .
# AT           .
# ATO          .
# ATW          .
# AUO          .
# ALV          .
# AN           .
# AZO          .
# AVB          .
# ACP          .
# AVY          .
# AVA          .
# AV           .
# AVV          .
# AVT          .
# AVP          .
# AVX          .
# AXLL         .
# AXS          .
# AZZ          .
# BGS          .
# MCI          .
# MPV          .
# BMI          .
# BHI          .
# BBN          .
# BLL          .
# BANC         .
# BBVA         .
# BBD          .
# BCH          .
# BLX          .
# BSBR         .
# BSAC         .
# SAN          .
# CIB          .
# BXS          .
# BAC          .
# BOH          .
# BMO          .
# BK           .
# BNS          .
# RATE         .
# BKU          .
# BCS          .
# BKS          .
# B            .
# ABX          .
# BAS          .
# BAX          .
# BTE          .
# BBT          .
# BFR          .
# BBX          .
# BCE          .
# TZF          .
# BZH          .
# BDX          .
# BDC          0.0137441063
# BXE          .
# BEL          .
# BMS          .
# BHE          .
# BHLB         .
# BBY          .
# BHP          .
# BBL          .
# BIG          .
# BH           .
# BBG          .
# BMR          .
# BIO          .
# BITA         .
# BKH          .
# BJZ          .
# BFZ          .
# CII          .
# BHK          .
# HYT          .
# BTZ          .
# DSU          .
# BHL          .
# BGR          .
# BDJ          .
# EGF          .
# FRA          .
# BFO          .
# BGT          .
# BOE          .
# BME          .
# BAF          .
# BKT          .
# BGY          0.0066136751
# BKN          .
# BTA          .
# MUI          .
# MNE          .
# MUA          .
# BPK          .
# BKK          .
# BIE          .
# BBK          .
# BBF          .
# BYM          .
# BFK          .
# MEN          .
# MUC          .
# MUH          .
# MHD          .
# MFL          .
# MUJ          .
# MHN          .
# MUE          .
# MUS          .
# MVT          .
# MYC          .
# MCA          .
# MYD          .
# MYF          .
# MFT          .
# MIY          .
# MYJ          .
# MYN          .
# MPA          .
# MQT          .
# MYI          .
# MQY          .
# BNJ          .
# BNY          .
# BLH          .
# BQH          .
# BSE          .
# BCX          .
# BSD          .
# BUI          .
# BLK          .
# BSL          .
# BLT          .
# BXC          .
# BWP          .
# BA           .
# BCEI         .
# BAH          .
# BWA          .
# SAM          .
# BXP          .
# BSX          .
# TEU          .
# BYD          .
# BP           .
# BPT          .
# BRC          .
# BDN          .
# BAK          .
# BRFS         .
# BPI          .
# BGG          .
# EAT          .
# BCO          .
# BMY          .
# BRS          .
# BR           .
# BKD          .
# BAM          .
# INF          .
# HHY          .
# BIP          .
# BEP          .
# HTR          .
# BRO          .
# BRT          .
# BC           .
# BT           .
# BPL          .
# BKE          .
# BVN          .
# BBW          .
# BG           .
# BWXT         .
# CJES         .
# BCR          .
# GYB          .
# PFH          .
# CAB          .
# CVC          .
# CBT          .
# COG          .
# CACI         .
# CAE          .
# CAI          .
# CAA          .
# CAL          .
# CCC          .
# CWT          .
# CALX         .
# ELY          .
# CPE          .
# CPN          .
# CBM          .
# CPT          .
# CCJ          .
# CAM          .
# CPB          .
# CCG          .
# CM           .
# CNI          .
# CNQ          .
# CP           .
# CAJ          .
# CMN          .
# COF          .
# CSU          .
# BXMT         .
# CMO          .
# CRR          .
# CAH          .
# CSL          .
# KMX          .
# CCL          .
# CUK          .
# CRS          .
# CSV          .
# CRI          .
# CSH          .
# CAS          .
# CAT          .
# CATO         .
# CBZ          .
# CBL          .
# IGR          .
# CBG          0.0067998514
# CBS          .
# CBS.A        .
# CDI          .
# CEB          0.0008230538
# FUN          .
# CDR          .
# CGI          .
# CE           .
# CLS          .
# CEL          .
# CX           .
# CNCO         .
# CVE          .
# CNC          .
# CNP          .
# EBR          .
# EBR.B        .
# CEE          .
# CTL          .
# CVO          .
# CF           .
# CGG          .
# GIB          .
# CRL          .
# CLDT         .
# CKP          .
# CHE          .
# CHMT         .
# CHK          .
# CHKR         .
# CHSP         .
# CPK          .
# CVX          .
# CBI          .
# CHS          .
# CIM          .
# CO           .
# STV          .
# DL           .
# CEA          .
# CHN          .
# CGA          .
# LFC          .
# MY           .
# CHL          .
# NPD          .
# BORN         .
# SNP          .
# ZNH          .
# CHA          .
# CHU          .
# XNY          .
# CYD          .
# ZX           .
# CMG          .
# CHH          .
# CBK          .
# CB           .
# CHT          .
# CHD          .
# CBR          .
# CIEN         .
# CI           .
# XEC          .
# CBB          .
# CNK          .
# CIR          .
# CIT          .
# BLW          .
# C            .
# CIA          .
# CLC          .
# CWEI         .
# CLH          .
# CCO          .
# CEM          .
# EMO          .
# CLW          .
# CNL          .
# CLF          .
# CLX          .
# CLD          .
# CMS          .
# CNA          .
# CNO          .
# CEO          .
# COH          .
# CIE          .
# KOF          .
# KO           .
# CCE          .
# CDE          .
# FOF          .
# INB          .
# UTF          .
# RQI          .
# RNP          .
# PSF          .
# RFI          .
# CNS          .
# CFX          .
# CL           .
# CXE          .
# CIF          .
# CXH          .
# CMU          .
# CLNY         .
# STK          .
# CCZ          .
# CMA          .
# FIX          .
# CMC          .
# CBU          .
# CYH          .
# CIG          .
# CIG.C        .
# CBD          .
# SBS          .
# ELP          .
# CCU          .
# CODI         .
# CMP          .
# CSC          .
# CRK          .
# CAG          .
# CXO          .
# CCM          .
# COP          .
# CNX          .
# ED           .
# STZ          .
# CLR          .
# CVG          .
# COO          .
# CTB          .
# CPS          .
# CPA          .
# CLB          .
# CLGX         .
# CORR         .
# COR          .
# GLW          .
# BCA          .
# GYC          .
# OFC          .
# CXW          .
# CZZ          .
# CMRE         .
# COT          .
# CCSC         .
# CUZ          .
# CVA          .
# CPF          .
# CPL          .
# CR           .
# BAP          .
# CS           .
# CPG          .
# CEQP         .
# CRH          .
# CRT          .
# CCI          .
# CCK          .
# CRY          .
# CSS          .
# CSX          .
# CTS          .
# CUBE         .
# CUB          .
# CFR          .
# CFI          .
# CMI          .
# CW           .
# CSI          .
# CVI          .
# UAN          .
# CVS          .
# CYS          .
# CYT          .
# DHI          .
# DAN          .
# DHR          .
# DAC          .
# DQ           .
# DRI          .
# DAR          .
# DVA          .
# DPM          .
# DCT          .
# DDR          .
# DF           .
# DECK         .
# DE           .
# DEX          .
# DDF          .
# DK           .
# DLPH         .
# DAL          .
# DEL          .
# DLX          .
# DMD          .
# DNR          .
# DKT          .
# DB           .
# DTK          .
# DXB          .
# DVN          .
# DV           .
# DHX          .
# DHT          .
# DEO          .
# DO           .
# DRH          .
# DSX          .
# DKS          .
# DBD          .
# DLR          .
# DGI          .
# DDS          .
# DDT          .
# DIN          .
# DFS          .
# DNI          .
# DLB          .
# DG           .
# DDC          .
# DOM          .
# D            .
# DPZ          .
# UFS          .
# DCI          .
# PLOW         .
# DEI          .
# DOV          .
# DDE          .
# DVD          .
# DOW          .
# DPS          .
# RDY          .
# DRD          .
# DW           .
# DHF          .
# DSM          .
# LEO          .
# DRQ          .
# DST          .
# DSW          .
# DTE          .
# DTZ          .
# DCO          .
# DPG          .
# DNP          .
# DTF          .
# DUC          .
# DUK          .
# DRE          .
# DNB          .
# DFT          .
# DHG          .
# DY           .
# DX           .
# DD           .
# SSP          .
# EXP          .
# EGP          .
# EMN          .
# ETN          .
# ETV          .
# ETW          .
# EV           .
# EOI          .
# EOS          .
# EFT          .
# EOT          .
# EVN          .
# ETJ          .
# EFR          .
# EVF          .
# EVG          .
# EVT          .
# ETO          .
# EXD          .
# ETG          .
# ETB          .
# ETY          .
# EXG          .
# ECT          .
# ECL          .
# DANG         .
# EC           .
# EIX          .
# EDR          .
# EW           .
# EJ           .
# EE           .
# EGO          .
# LLY          .
# ELLI         .
# EFC          .
# ERJ          .
# EMC          .
# EME          .
# EBS          .
# EMG          .
# EMR          .
# EDE          .
# EIG          .
# EDN          .
# EOC          .
# ICA          .
# EEQ          .
# EEP          .
# ENB          .
# ECA          .
# EXK          .
# ENH          .
# NDRO         .
# EGN          .
# EPC          .
# ETE          .
# ETP          .
# ERF          .
# ENI          .
# ENS          .
# E            .
# ENLK         .
# ENLC         .
# EBF          .
# NPO          .
# ESV          .
# ETM          .
# EAA          .
# ETR          .
# ELA          .
# ELB          .
# EFM          .
# EMQ          .
# EMZ          .
# EPD          .
# EVC          .
# ENV          .
# ENZ          .
# EOG          .
# EPR          .
# EQT          .
# EFX          .
# EQC          .
# ELS          .
# EQY          .
# EQR          .
# EQS          .
# ESE          .
# ESS          .
# EL           .
# ESL          .
# DEG          .
# ETH          .
# EEA          .
# EVR          .
# RE           .
# EVRI         .
# ES           .
# EVGN         .
# EXAM         .
# EXAR         .
# XCO          .
# EXC          .
# EXPR         .
# EXR          .
# XOM          .
# FNB          .
# FN           .
# FDS          .
# FICO         .
# FFG          .
# AGM          .
# FRT          .
# FSS          .
# FII          .
# FPT          .
# FMN          .
# FDX          .
# FCH          .
# FGP          .
# FOE          .
# FCAU         .
# FBR          .
# FNF          .
# FIS          .
# FMO          .
# FAC          .
# FAF          .
# FBP          .
# FCF          .
# FHN          .
# FR           .
# AG           .
# FMD          .
# FPO          .
# FRC          .
# FFA          .
# FMY          .
# FAV          .
# FIF          .
# FSD          .
# FCT          .
# FGB          .
# FHY          .
# FEO          .
# FAM          .
# FE           .
# FVE          .
# FBC          .
# PFD          .
# PFO          .
# FFC          .
# FLC          .
# FLT          .
# FTK          .
# FLO          .
# FLS          .
# FLR          .
# FLY          .
# FMC          .
# FTI          .
# FMX          .
# FL           .
# F            .
# FOR          .
# FDI          .
# FIG          .
# FSM          .
# FBHS         .
# FNV          .
# FC           .
# BEN          .
# FT           .
# FCX          .
# FSL          .
# FMS          .
# FDP          .
# FRO          .
# FCN          .
# FRM          .
# FF           .
# FXCM         .
# GCV          .
# GDV          .
# GAB          .
# GGT          .
# GUT          .
# GFA          .
# GCAP         .
# GBL          .
# GNT          .
# GME          .
# GPS          .
# IT           .
# GMT          .
# GZT          .
# GNRC         .
# GAM          0.0323378003
# BGC          .
# GD           .
# GE           .
# GGP          .
# GIS          .
# GM           .
# GSI          .
# GCO          .
# GWR          .
# GEL          .
# GNE          .
# G            .
# GPC          .
# GNW          .
# GEO          .
# GGB          .
# GTY          .
# GIL          .
# GLT          .
# GSK          .
# GHI          .
# GLP          .
# GPN          .
# GLPW         .
# GSL          .
# GNC          .
# GOL          .
# GFI          .
# GG           .
# GS           .
# TFG          .
# GDP          .
# GOV          .
# GPX          .
# GGG          .
# GHM          .
# GHC          .
# GPT          .
# GVA          .
# GPK          .
# GTN          .
# GXP          .
# GB           .
# GDOT         .
# GBX          .
# GHL          .
# GEF          .
# GFF          .
# GPI          .
# PAC          .
# ASR          .
# TV           .
# GTT          .
# GSH          .
# GES          .
# GBAB         .
# GPM          .
# GGE          .
# GEQ          .
# GOF          .
# GUA          .
# GLF          .
# HRB          .
# FUL          .
# HAE          .
# HK           .
# HAL          .
# HBI          .
# HGR          .
# HOG          .
# HAR          .
# HMY          .
# HRS          .
# HSC          .
# HHS          .
# HIG          .
# HNR          .
# HTS          .
# HVT          .
# HE           .
# HCA          .
# HCI          .
# HCP          .
# HDB          .
# HW           .
# HNT          .
# HR           .
# HLS          0.0068318808
# HPY          .
# HL           .
# HEI          .
# HLX          .
# HP           .
# HLF          .
# HTGC         .
# HT           .
# HSY          .
# HTZ          .
# HES          .
# HXL          .
# HF           .
# HGG          .
# HIW          .
# HIL          .
# HI           .
# HRC          .
# HTH          .
# HNI          .
# HEP          .
# HFC          .
# HD           .
# HMC          .
# HON          .
# HMN          .
# HRL          .
# HOS          .
# HPT          .
# HST          .
# HOV          .
# HHC          .
# HPQ          .
# HRG          .
# HSBC         .
# HSEA         .
# HSEB         .
# HNP          .
# HBM          .
# HPP          .
# HGT          .
# HUM          .
# HII          .
# HUN          .
# H            .
# IAG          .
# IBN          .
# IDA          .
# IEX          .
# IDT          .
# IHS          .
# ITW          .
# IMN          .
# IMAX         .
# IMPV         .
# IHC          .
# IFN          .
# IBA          .
# INFY         .
# IND          .
# ING          .
# INZ          .
# ISF          .
# ISG          .
# ISP          .
# IR           .
# IM           .
# INGR         .
# IRC          .
# IPHI         .
# NSP          .
# ICE          .
# IHG          .
# IFF          .
# IBM          .
# IGT          .
# IP           .
# ISH          .
# IOC          .
# IPG          .
# INXN         .
# IL           .
# IPI          .
# IVC          .
# INVN         .
# VBF          .
# VCV          .
# VTA          .
# VLT          .
# IVR          .
# OIA          .
# VMO          .
# VKQ          .
# VPV          .
# IVZ          .
# IQI          .
# VVR          .
# VTN          .
# VGM          .
# IIM          .
# ITG          .
# IRET         .
# IO           .
# IRM          .
# IRS          .
# ITUB         .
# ITC          .
# ITT          .
# ESI          .
# JPM          .
# JCP          .
# SJM          .
# JBL          .
# JEC          .
# JHX          .
# JNS          .
# JOF          .
# JAH          .
# JKS          .
# JMP          .
# JBT          .
# BTO          .
# HEQ          .
# JHS          .
# JHI          .
# HPF          .
# HPI          .
# HPS          .
# PDT          .
# HTD          .
# HTY          .
# JNJ          .
# JCI          .
# JLL          .
# JOY          .
# JFC          .
# JNPR         .
# JE           .
# LRN          .
# KAI          .
# KAMN         .
# KSU          .
# KS           .
# KAR          .
# KATE         .
# KED          .
# KYE          .
# KMF          .
# KYN          .
# KB           .
# KBH          .
# KBR          .
# K            .
# KEM          .
# KMPR         .
# KMT          .
# KW           .
# KEG          .
# KEY          .
# KRC          .
# KMB          .
# KIM          .
# KMI          .
# KND          .
# KFS          .
# KGC          .
# KEX          .
# KRG          .
# KKR          .
# KFH          .
# KMG          .
# KNX          .
# KNL          .
# KSS          .
# PHG          .
# KOP          .
# KEP          .
# KEF          .
# KF           .
# KFY          .
# KOS          .
# KRA          .
# KKD          .
# KR           .
# KRO          .
# KT           .
# KYO          .
# LB           .
# SCX          .
# LLL          .
# LH           .
# LG           .
# LDR          .
# LCI          .
# LPI          .
# LVS          .
# LHO          .
# LFL          .
# LDF          .
# LGI          0.0210709337
# LAZ          .
# LOR          .
# LZB          .
# LF           .
# LEA          .
# LEE          .
# LM           .
# LEG          .
# CVB          .
# JBK          .
# KCC          .
# KTH          .
# KTN          .
# KTP          .
# XKE          .
# LDOS         .
# LEN          .
# LII          .
# LUK          .
# LVLT         .
# LXP          .
# LXK          .
# LPL          .
# ASG          .
# LPT          .
# LNC          .
# LNN          .
# LNKD         .
# LGF          .
# LAD          .
# LYV          .
# LYG          .
# SCD          .
# TLI          .
# RIT          .
# LMT          .
# L            .
# LPX          .
# LOW          .
# LXU          .
# LTC          .
# LUB          .
# LL           .
# LUX          .
# LDL          .
# LYB          .
# MTB          .
# MDC          .
# MHO          .
# MAC          .
# CLI          .
# MGU          .
# MIC          .
# MFD          .
# BMA          .
# M            .
# MCN          .
# MSP          .
# MMP          .
# MGA          .
# MX           .
# MHNA         .
# MAIN         .
# MZF          .
# HYF          .
# MTW          .
# MN           .
# MAN          .
# MFC          .
# MRO          .
# MPC          .
# MCS          .
# MHG          .
# MPX          .
# HZO          .
# MKL          .
# MWE          .
# VAC          .
# MMC          .
# MSO          .
# MLM          .
# MAS          .
# DOOR         .
# MTZ          .
# MA           .
# MTRN         .
# MATX         .
# MLP          .
# MMS          .
# MXL          .
# MBI          .
# MNI          .
# MKC          .
# MDR          .
# MCD          .
# MUX          .
# MHFI         .
# MCK          .
# MDU          .
# MJN          .
# MTL          .
# MEG          .
# MPW          .
# MED          .
# MCC          .
# MD           0.0096089494
# MDT          .
# MW           .
# MRK          .
# MCY          .
# MDP          .
# MTH          .
# MTOR         .
# PIY          .
# MTR          .
# MSB          .
# MEI          .
# MET          .
# MTD          .
# MXE          .
# MXF          .
# MFA          .
# MIL          .
# MCR          .
# MGF          .
# MIN          .
# MMT          .
# MFM          .
# MFV          .
# MTG          .
# MGM          .
# KORS         .
# MAA          .
# MSL          .
# MLR          .
# MR           .
# MTX          .
# MG           .
# MTU          .
# MFG          .
# MBT          .
# MOD          .
# MHK          .
# MOH          .
# TAP          .
# TAP.A        .
# MNR          .
# MON          .
# MWW          .
# MTS          .
# MCO          .
# MS           .
# MSK          .
# MWG          .
# MWO          .
# MWR          .
# APF          .
# CAF          .
# MSD          .
# EDD          .
# MSF          0.0646769436
# IIF          .
# MOS          .
# MSI          .
# MOV          .
# ICB          .
# HJV          .
# MSA          .
# MSM          .
# MSCI         .
# MSGN         .
# MLI          .
# MWA          .
# MUR          .
# MVO          .
# MVC          .
# MYE          .
# NBR          .
# NC           .
# NTP          .
# NBG          .
# NFG          .
# NGG          .
# NHI          .
# NOV          .
# NPK          .
# NNN          .
# SID          .
# NGS          .
# NRP          .
# NTZ          .
# NLS          .
# NCI          .
# NVGS         .
# NNA          .
# NM           .
# NMM          .
# NAV          .
# NCS          .
# NCR          .
# NP           .
# NNI          .
# NPTN         .
# N            .
# NSR          .
# HYB          .
# GF           .
# IRL          .
# NMFC         .
# EDU          .
# NWY          .
# NYCB         .
# NYT          .
# NCT          .
# NWL          .
# NFX          .
# NJR          .
# NEU          .
# NEM          .
# NR           .
# NHF          .
# NEE          .
# NGL          .
# NJ           .
# NLSN         .
# NKE          .
# NTT          .
# NKA          .
# NI           .
# NL           .
# NOAH         .
# NE           .
# NBL          .
# NOK          .
# NMR          .
# NOR          .
# NAT          .
# JWN          .
# NSC          .
# NTL          .
# NOA          .
# NRT          .
# NOC          .
# NRF          .
# NWN          .
# NWE          .
# NVS          .
# NVO          .
# NQ           .
# NRG          .
# DCM          .
# NUS          .
# NUE          .
# NS           .
# NSH          .
# NEA          .
# NUV          .
# NUW          .
# NAZ          .
# NBB          .
# NBD          .
# NKX          .
# NAC          .
# NCA          .
# NTC          .
# JCE          .
# JQC          .
# JDD          .
# NAD          .
# JMF          .
# NEV          .
# JFR          .
# JRO          .
# NKG          .
# JGV          .
# NXC          .
# NXN          .
# NQM          .
# NMY          .
# NMT          .
# NUM          .
# JLS          .
# JMM          .
# NMA          .
# NMI          .
# NMO          .
# NIO          .
# NXJ          .
# NRK          .
# NAN          .
# NNY          .
# NNC          .
# NUO          .
# NQP          .
# NPP          .
# JPC          .
# NPF          .
# NPM          .
# NPT          .
# NPI          .
# NQU          .
# NQI          .
# JTP          .
# JPS          .
# JHP          .
# BXMX         .
# SPXX         .
# NIM          .
# NQS          .
# NXP          .
# NXQ          .
# NXR          .
# NSL          .
# JSD          .
# JTD          .
# JTA          .
# NTX          .
# NPV          .
# JMT          .
# NES          .
# NVR          .
# OAS          .
# OXY          .
# OII          .
# OZM          .
# OCN          .
# OFG          .
# OGE          .
# OIBR         .
# OIBR.C       .
# OIS          .
# ODC          .
# ORI          .
# OLN          .
# OHI          .
# OME          .
# OMC          .
# OMN          .
# ASGN         .
# OLP          .
# OB           .
# OKS          .
# OKE          .
# OPK          .
# OPY          .
# ORCL         .
# ORAN         .
# OA           .
# ORN          .
# IX           .
# ORA          .
# OSK          .
# OMI          .
# OC           .
# OI           .
# OXM          .
# PAI          .
# PACD         .
# PCG          .
# PKG          .
# PAM          .
# P            .
# PHX          .
# PAR          .
# PKE          .
# PKD          .
# PH           .
# PKY          .
# PRE          .
# SDT          .
# PER          .
# SNY          .
# SAP          .
# SAR          .
# SSL          .
# BFS          .
# SCG          .
# SLB          .
# SWM          .
# STNG         .
# SMG          .
# SNI          .
# LBF          .
# KHI          .
# KMM          .
# KTF          .
# KST          .
# KSM          .
# SA           .
# CKH          .
# SDRL         .
# SEE          .
# SSW          .
# JBN          .
# JBR          .
# SEM          .
# SEMG         .
# SMI          .
# SRE          .
# SNH          .
# SXT          .
# SQNS         .
# SCI          .
# SJR          .
# SHW          .
# SHG          .
# SFL          .
# SIG          .
# SLW          .
# SPG          .
# SSD          .
# SHI          .
# SIX          .
# SJW          .
# SKM          .
# SKX          .
# SLG          .
# SM           .
# SNN          .
# AOS          .
# SNA          .
# SQM          .
# SWI          .
# SLH          .
# SAH          .
# SON          .
# SNE          .
# BID          .
# SFUN         .
# SOR          .
# SJI          .
# SO           .
# SCCO         .
# LUV          .
# SWX          .
# SWN          .
# SSS          .
# SPA          .
# SPE          .
# SE           .
# SEP          .
# TRK          .
# SPR          .
# S            .
# SPXC         .
# JOE          .
# STJ          .
# STAG         .
# SSI          .
# SFG          .
# SMP          .
# SXI          .
# SWK          .
# SWU          .
# STN          .
# SGU          .
# SRT          .
# HOT          .
# STWD         .
# STT          .
# STO          .
# SCS          .
# SCL          .
# STE          .
# STL          .
# STC          .
# SWC          .
# STM          .
# SGY          .
# EDF          .
# STON         .
# SRI          .
# SGL          .
# BEE          .
# SYK          .
# RGR          .
# SPH          .
# SMFG         .
# INN          .
# SUI          .
# SLF          .
# SXC          .
# SU           .
# SUNE         .
# SXL          .
# SHO          .
# STI          .
# SPN          .
# SUP          .
# SVU          .
# SFY          .
# SWFT         .
# SWZ          .
# SYA          .
# SYT          .
# SNX          .
# SNV          .
# GJH          .
# GJO          .
# GJS          .
# GJP          .
# GJR          .
# GJT          .
# GJV          .
# SYY          .
# SYX          .
# TAHO         .
# TWN          .
# TSM          .
# XRS          .
# TAL          .
# SKT          .
# TAOM         .
# NGLS         .
# TRGP         .
# TGT          .
# TARO         .
# TTM          .
# TCP          .
# TCB          .
# TSI          .
# AMTD         .
# TEL          .
# TMH          .
# TISI         .
# TCK          .
# TE           .
# TK           .
# TGP          .
# TOO          .
# TNK          .
# TGNA         .
# TRC          .
# HQH          .
# HQL          .
# TEO          .
# TI           .
# TDY          .
# TFX          .
# VIV          .
# TEF          .
# TDE          .
# TDI          .
# TDJ          .
# TDS          .
# TU           .
# TDF          .
# EMF          .
# TEI          .
# GIM          .
# TRF          .
# TPX          .
# TS           .
# THC          .
# TNC          .
# TEN          .
# TVC          .
# TVE          .
# TDC          .
# TER          .
# TEX          .
# TX           .
# TNH          .
# TRNO         .
# TSO          .
# TLLP         .
# TTI          .
# TEVA         .
# TPL          .
# TGH          .
# TXT          .
# TTF          .
# AES          .
# BX           .
# SCHW         .
# SRV          .
# GRX          .
# GDL          .
# THG          .
# TRV          .
# TMO          .
# THR          .
# TC           .
# TRI          .
# THO          .
# TDW          .
# TIF          .
# TSU          .
# TWC          .
# TWX          .
# TKR          .
# TWI          .
# TJX          .
# TOL          .
# TR           .
# TMK          0.0079454325
# TTC          .
# TD           .
# NTG          .
# TTP          .
# TPZ          .
# TSS          .
# TOT          .
# TOWR         .
# TM           .
# TAC          .
# TAI          .
# TRP          .
# TCI          .
# TDG          .
# TLP          .
# RIG          .
# TGS          .
# TA           .
# TRR          .
# TREC         .
# TG           .
# THS          .
# TREX         .
# TY           0.0697633062
# TCAP         .
# TSL          .
# TRN          .
# GTS          .
# TGI          .
# TROX         .
# TBI          .
# TNP          .
# TUP          .
# TKC          .
# TKF          .
# TRQ          .
# TPC          .
# TWO          .
# TYC          .
# TYL          .
# TSN          .
# USB          .
# USPH         .
# UGI          .
# UIL          .
# UPL          .
# UGP          .
# UMH          .
# UA           .
# UFI          .
# UNF          .
# UN           .
# UL           .
# UNP          .
# UIS          .
# UNT          .
# UAL          .
# UDR          .
# UMC          .
# UPS          .
# URI          .
# USM          .
# UZA          .
# X            .
# UTX          .
# UNH          .
# UTL          .
# UAM          .
# UVV          .
# UHT          .
# UHS          .
# UVE          .
# UTI          .
# UNM          .
# UBA          .
# UBP          .
# USNA         .
# USG          .
# BIF          .
# VFC          .
# EGY          .
# MTN          .
# VALE         .
# VRX          .
# VLO          .
# VHI          .
# VR           .
# VLY          .
# VMI          .
# VAL          .
# VAR          .
# VGR          .
# VVC          .
# VEDL         .
# VTR          .
# VER          .
# PAY          .
# VZ           .
# VET          .
# VVI          .
# VCO          .
# DCA          .
# V            .
# VSH          .
# VPG          .
# VC           .
# VSI          .
# VMW          .
# VOC          .
# VG           .
# VNO          .
# IAE          .
# IHD          .
# IGA          .
# IGD          .
# IDE          .
# IID          .
# IRR          .
# PPR          .
# VMC          .
# WTI          .
# WPC          .
# WRB          .
# GRA          .
# GWW          .
# WNC          .
# WBC          .
# WDR          .
# WD           .
# WMT          .
# DIS          .
# WAC          .
# WRE          .
# WCN          .
# WM           .
# WAT          .
# WSO          .
# WTS          .
# WPP          .
# WFT          .
# WBS          .
# WEC          .
# WTW          .
# WRI          .
# WMK          .
# WCG          .
# WFC          .
# EOD          .
# HCN          .
# WAIR         .
# WCC          .
# WST          .
# WR           .
# WAL          .
# WEA          .
# ESD          .
# EMD          .
# GDO          .
# EHI          .
# GDF          .
# HIX          .
# HIO          .
# HYI          .
# IGI          .
# MHY          .
# MMU          .
# DMO          .
# MTT          .
# MHF          .
# MNP          .
# GFY          .
# SBW          .
# WIW          .
# WIA          .
# WES          .
# WNR          .
# WU           .
# WAB          .
# WLK          .
# WMLP         .
# WBK          .
# WHG          .
# WEX          .
# WY           .
# WGL          .
# WHR          .
# WTM          .
# WSR          .
# WLL          .
# WG           .
# WMB          .
# WPZ          .
# WSM          .
# WSH          .
# WGO          .
# FUR          .
# WIT          .
# WNS          .
# WWW          .
# WF           .
# INT          .
# WWE          .
# WOR          .
# WPX          .
# WX           .
# WYN          .
# XEL          .
# XRM          .
# XRX          .
# XIN          .
# XL           .
# XOXO         .
# XPO          .
# XUE          .
# XYL          .
# AUY          .
# YZC          .
# YGE          .
# YOKU         .
# YPF          .
# YUM          .
# ZBH          .
# ZF           .
# ZTR          .

# %%
# %%R
#
# beta_lasso_nz = beta_lasso[beta_lasso!=0]
# names(beta_lasso_nz) = names(beta_lasso)[beta_lasso!=0]
# print(beta_lasso_nz)
# Out:
#  [1] -0.0001066996  0.0011158914  0.0028075581  0.0137441063  0.0066136751
#  [6]  0.0067998514  0.0008230538  0.0323378003  0.0068318808  0.0210709337
# [11]  0.0096089494  0.0646769436  0.0079454325  0.0697633062

# %% [markdown]
# ---
